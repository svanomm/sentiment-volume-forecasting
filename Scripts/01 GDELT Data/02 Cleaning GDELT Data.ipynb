# %%
import pandas as pd
import polars as pl
import numpy as np

# %%
df = pl.read_csv('../../data/processed/gdelt_combined_20250609_1222.csv')

# %%
df = df.select(pl.all().shrink_dtype())

# %%
df
# Out:
# shape: (978_850, 3_019)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ GKGRECORD ┆ V2SOURCEC ┆ V2SOURCEC ┆ V2DOCUMEN ┆ … ┆ v42.8;    ┆ v42.9;    ┆ v42.10;   ┆ v42.11;  │
# │ ID        ┆ OLLECTION ┆ OMMONNAME ┆ TIDENTIFI ┆   ┆ SCOREDVAL ┆ SCOREDVAL ┆ SCOREDVAL ┆ SCOREDVA │
# │ ---       ┆ IDENTIFIE ┆ ---       ┆ ER        ┆   ┆ UE; fairn ┆ UE; loyal ┆ UE; autho ┆ LUE; san │
# │ str       ┆ R         ┆ str       ┆ ---       ┆   ┆ ess_s…    ┆ ty_se…    ┆ rity…     ┆ ctity_…  │
# │           ┆ ---       ┆           ┆ str       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆ i64       ┆           ┆           ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 202302210 ┆ 1         ┆ aero-news ┆ http://ae ┆ … ┆ -0.047186 ┆ -0.009921 ┆ -0.062596 ┆ -0.07546 │
# │ 30000-453 ┆           ┆ .net      ┆ ro-news.n ┆   ┆           ┆           ┆           ┆ 7        │
# │           ┆           ┆           ┆ et/index. ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ cfm…      ┆   ┆           ┆           ┆           ┆          │
# │ 202407121 ┆ 1         ┆ thepoints ┆ http://th ┆ … ┆ 0.044717  ┆ 0.059077  ┆ 0.019955  ┆ 0.005432 │
# │ 73000-741 ┆           ┆ guy.com   ┆ epointsgu ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ y.com/cre ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ dit…      ┆   ┆           ┆           ┆           ┆          │
# │ 202407121 ┆ 1         ┆ thepoints ┆ http://th ┆ … ┆ 0.036619  ┆ 0.044447  ┆ 0.018907  ┆ -0.00481 │
# │ 73000-33  ┆           ┆ guy.com   ┆ epointsgu ┆   ┆           ┆           ┆           ┆ 5        │
# │           ┆           ┆           ┆ y.com/cre ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ dit…      ┆   ┆           ┆           ┆           ┆          │
# │ 202407151 ┆ 1         ┆ thepoints ┆ http://th ┆ … ┆ 0.072625  ┆ 0.062866  ┆ 0.006874  ┆ 0.006023 │
# │ 63000-8   ┆           ┆ guy.com   ┆ epointsgu ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ y.com/cre ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ dit…      ┆   ┆           ┆           ┆           ┆          │
# │ 202407151 ┆ 1         ┆ thepoints ┆ http://th ┆ … ┆ 0.048766  ┆ 0.039277  ┆ 0.074819  ┆ 0.042827 │
# │ 63000-163 ┆           ┆ guy.com   ┆ epointsgu ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ y.com/new ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ s/a…      ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 202205091 ┆ 1         ┆ yachtsand ┆ https://w ┆ … ┆ 0.08696   ┆ 0.063988  ┆ 0.060735  ┆ 0.088388 │
# │ 24500-150 ┆           ┆ yachting. ┆ ww.yachts ┆   ┆           ┆           ┆           ┆          │
# │ 7         ┆           ┆ com       ┆ andyachti ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ ng.…      ┆   ┆           ┆           ┆           ┆          │
# │ 202007151 ┆ 1         ┆ yumasun.c ┆ https://w ┆ … ┆ -0.026376 ┆ 0.025336  ┆ -0.01564  ┆ -0.04204 │
# │ 73000-707 ┆           ┆ om        ┆ ww.yumasu ┆   ┆           ┆           ┆           ┆ 8        │
# │           ┆           ┆           ┆ n.com/new ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ s/n…      ┆   ┆           ┆           ┆           ┆          │
# │ 202108202 ┆ 1         ┆ iheart.co ┆ https://w ┆ … ┆ 0.025083  ┆ 0.049848  ┆ 0.071437  ┆ 0.103279 │
# │ 04500-745 ┆           ┆ m         ┆ ynkcountr ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ y.iheart. ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ com…      ┆   ┆           ┆           ┆           ┆          │
# │ 202203020 ┆ 1         ┆ y95countr ┆ https://y ┆ … ┆ 0.005834  ┆ 0.032754  ┆ 0.065639  ┆ 0.005686 │
# │ 21500-144 ┆           ┆ y.com     ┆ 95country ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .com/twic ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ e-d…      ┆   ┆           ┆           ┆           ┆          │
# │ 202203020 ┆ 1         ┆ india.com ┆ https://z ┆ … ┆ -0.075383 ┆ -0.011974 ┆ -0.031635 ┆ -0.04977 │
# │ 13000-914 ┆           ┆           ┆ eenews.in ┆   ┆           ┆           ┆           ┆ 4        │
# │           ┆           ┆           ┆ dia.com/w ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ orl…      ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
title_counts = df['article_title'].value_counts().to_pandas()

# %%
title_counts
# Out:
#                                             article_title  count
# 0       Southwest passengers on Viasat-fitted 737 can ...      1
# 1        Eyewitness on the joy of baby boy born on flight      1
# 2       Travel PR News | Southwest Airlines launched a...      1
# 3       Frontier Airlines launches 'All-You-Can-Fly' a...      1
# 4       'Aggressive' Return To Travel Shifts Bottlenec...      1
# ...                                                   ...    ...
# 314074  FAA clears path for Boeing's grounded planes t...      1
# 314075  First-ever Oneworld branded lounge to open at ...      1
# 314076  Jerry Jones Accuses Woman of Extortion, Paid M...      3
# 314077  Ugly truth about the Kennedy dynasty and the l...      1
# 314078  Traveler Tests Positive for COVID-19 Upon Arri...      1
#
# [314079 rows x 2 columns]

# %%
# Remove a list of titles that are probably home pages or other non-article content
titles_to_remove = [
    'News briefs',
    'Latest Articles',
    'The Nashville Ledger',
    'Today in History',
    'National News - Media One Radio Group (WWSE | WJTN | WHUG | WKSN | WQFX',
    "Aero-News Network: The aviation and aerospace world's daily/real-time news and information service",
    'Drake & 21 Savage Add More Texas Concert Dates Due To High Demand',
    'Stock Market | FinancialContent Business Page',
    'Radio Station WHMI 93.5 FM &#x2014; Livingston County Michigan News, Weather, Traffic, Sports, School Updates, and the Best Classic Hit',
    'National - KSYL-AM',
    'Business Highlights',
    'Business Highlights',
    'National News - 1540 WADK Newport',
    'National - Carroll Broadcasting Inc.',
    'ABC National - WOND',
    "Breaking National News - 92.7-FM TheDRIVE - Bob & Tom Mornings, Central New York's Best Rock All Day",
    "ABC - National News - Xtra 99.1 FM - Today's Hits and Yesterday's Favorites",
    "Ed Bruce, Legendary Country Songwriter, 'Maverick' Actor, Dead At 81",
    "ABC National News - Beach 95.1 - WBPC Panama City Beach Greatest Hits of the 60s, 70s & 80s",
    "CES gadget show: How watching TV will change in the 2020s",
    "Despite business warnings, GOP moves ahead with voting bills",
    "KTBB.com - News Weather Talk",
    "AP Story",
    "SRN - US News - Taylorville Daily News",
]

df = df.filter(
    ~df['article_title'].is_in(titles_to_remove)
)

# Replace empty article titles with z
df = df.with_columns(
    pl.when(pl.col('article_title') == '').then('z').otherwise(pl.col('article_title'))
)

# Drop where article_title contains 'AP News in Brief'
df = df.filter(
    ~df['article_title'].str.contains('AP News in Brief at', literal=True)
    )
# Out:
# ---------------------------------------------------------------------------
# ColumnNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 34
#      29 df = df.filter(
#      30     ~df['article_title'].is_in(titles_to_remove)
#      31 )
#      33 # Replace empty article titles with z
# ---> 34 df = df.with_columns(
#      35     pl.when(pl.col('article_title') == '').then('z').otherwise(pl.col('article_title'))
#      36 )
#      38 # Drop where article_title contains 'AP News in Brief'
#      39 df = df.filter(
#      40     ~df['article_title'].str.contains('AP News in Brief at', literal=True)
#      41     )
#
# File c:\Users\Steven\Desktop\school github repos\svo-directed-practicum\.venv\Lib\site-packages\polars\dataframe\frame.py:9938, in DataFrame.with_columns(self, *exprs, **named_exprs)
#    9792 """
#    9793 Add columns to this DataFrame.
#    9794
#    (...)   9931 └─────┴──────┴─────────────┘
#    9932 """
#    9933 from polars.lazyframe.opt_flags import QueryOptFlags
#    9935 return (
#    9936     self.lazy()
#    9937     .with_columns(*exprs, **named_exprs)
# -> 9938     .collect(optimizations=QueryOptFlags._eager())
#    9939 )
#
# File c:\Users\Steven\Desktop\school github repos\svo-directed-practicum\.venv\Lib\site-packages\polars\_utils\deprecation.py:97, in deprecate_streaming_parameter.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#      93         kwargs["engine"] = "in-memory"
#      95     del kwargs["streaming"]
# ---> 97 return function(*args, **kwargs)
#
# File c:\Users\Steven\Desktop\school github repos\svo-directed-practicum\.venv\Lib\site-packages\polars\lazyframe\opt_flags.py:331, in forward_old_opt_flags.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     328         optflags = cb(optflags, kwargs.pop(key))  # type: ignore[no-untyped-call,unused-ignore]
#     330 kwargs["optimizations"] = optflags
# --> 331 return function(*args, **kwargs)
#
# File c:\Users\Steven\Desktop\school github repos\svo-directed-practicum\.venv\Lib\site-packages\polars\lazyframe\frame.py:2300, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, engine, background, optimizations, **_kwargs)
#    2298 # Only for testing purposes
#    2299 callback = _kwargs.get("post_opt_callback", callback)
# -> 2300 return wrap_df(ldf.collect(engine, callback))
#
# ColumnNotFoundError: z

# %%
df
# Out:
# shape: (699_965, 3_019)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ GKGRECORD ┆ V2SOURCEC ┆ V2SOURCEC ┆ V2DOCUMEN ┆ … ┆ v42.8;    ┆ v42.9;    ┆ v42.10;   ┆ v42.11;  │
# │ ID        ┆ OLLECTION ┆ OMMONNAME ┆ TIDENTIFI ┆   ┆ SCOREDVAL ┆ SCOREDVAL ┆ SCOREDVAL ┆ SCOREDVA │
# │ ---       ┆ IDENTIFIE ┆ ---       ┆ ER        ┆   ┆ UE; fairn ┆ UE; loyal ┆ UE; autho ┆ LUE; san │
# │ str       ┆ R         ┆ str       ┆ ---       ┆   ┆ ess_s…    ┆ ty_se…    ┆ rity…     ┆ ctity_…  │
# │           ┆ ---       ┆           ┆ str       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---      │
# │           ┆ i64       ┆           ┆           ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64      │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ 202302210 ┆ 1         ┆ aero-news ┆ http://ae ┆ … ┆ -0.047186 ┆ -0.009921 ┆ -0.062596 ┆ -0.07546 │
# │ 30000-453 ┆           ┆ .net      ┆ ro-news.n ┆   ┆           ┆           ┆           ┆ 7        │
# │           ┆           ┆           ┆ et/index. ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ cfm…      ┆   ┆           ┆           ┆           ┆          │
# │ 202407121 ┆ 1         ┆ thepoints ┆ http://th ┆ … ┆ 0.044717  ┆ 0.059077  ┆ 0.019955  ┆ 0.005432 │
# │ 73000-741 ┆           ┆ guy.com   ┆ epointsgu ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ y.com/cre ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ dit…      ┆   ┆           ┆           ┆           ┆          │
# │ 202407121 ┆ 1         ┆ thepoints ┆ http://th ┆ … ┆ 0.036619  ┆ 0.044447  ┆ 0.018907  ┆ -0.00481 │
# │ 73000-33  ┆           ┆ guy.com   ┆ epointsgu ┆   ┆           ┆           ┆           ┆ 5        │
# │           ┆           ┆           ┆ y.com/cre ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ dit…      ┆   ┆           ┆           ┆           ┆          │
# │ 202407151 ┆ 1         ┆ thepoints ┆ http://th ┆ … ┆ 0.072625  ┆ 0.062866  ┆ 0.006874  ┆ 0.006023 │
# │ 63000-8   ┆           ┆ guy.com   ┆ epointsgu ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ y.com/cre ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ dit…      ┆   ┆           ┆           ┆           ┆          │
# │ 202407151 ┆ 1         ┆ thepoints ┆ http://th ┆ … ┆ 0.048766  ┆ 0.039277  ┆ 0.074819  ┆ 0.042827 │
# │ 63000-163 ┆           ┆ guy.com   ┆ epointsgu ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ y.com/new ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ s/a…      ┆   ┆           ┆           ┆           ┆          │
# │ …         ┆ …         ┆ …         ┆ …         ┆ … ┆ …         ┆ …         ┆ …         ┆ …        │
# │ 202205091 ┆ 1         ┆ yachtsand ┆ https://w ┆ … ┆ 0.08696   ┆ 0.063988  ┆ 0.060735  ┆ 0.088388 │
# │ 24500-150 ┆           ┆ yachting. ┆ ww.yachts ┆   ┆           ┆           ┆           ┆          │
# │ 7         ┆           ┆ com       ┆ andyachti ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ ng.…      ┆   ┆           ┆           ┆           ┆          │
# │ 202007151 ┆ 1         ┆ yumasun.c ┆ https://w ┆ … ┆ -0.026376 ┆ 0.025336  ┆ -0.01564  ┆ -0.04204 │
# │ 73000-707 ┆           ┆ om        ┆ ww.yumasu ┆   ┆           ┆           ┆           ┆ 8        │
# │           ┆           ┆           ┆ n.com/new ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ s/n…      ┆   ┆           ┆           ┆           ┆          │
# │ 202108202 ┆ 1         ┆ iheart.co ┆ https://w ┆ … ┆ 0.025083  ┆ 0.049848  ┆ 0.071437  ┆ 0.103279 │
# │ 04500-745 ┆           ┆ m         ┆ ynkcountr ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ y.iheart. ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ com…      ┆   ┆           ┆           ┆           ┆          │
# │ 202203020 ┆ 1         ┆ y95countr ┆ https://y ┆ … ┆ 0.005834  ┆ 0.032754  ┆ 0.065639  ┆ 0.005686 │
# │ 21500-144 ┆           ┆ y.com     ┆ 95country ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ .com/twic ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ e-d…      ┆   ┆           ┆           ┆           ┆          │
# │ 202203020 ┆ 1         ┆ india.com ┆ https://z ┆ … ┆ -0.075383 ┆ -0.011974 ┆ -0.031635 ┆ -0.04977 │
# │ 13000-914 ┆           ┆           ┆ eenews.in ┆   ┆           ┆           ┆           ┆ 4        │
# │           ┆           ┆           ┆ dia.com/w ┆   ┆           ┆           ┆           ┆          │
# │           ┆           ┆           ┆ orl…      ┆   ┆           ┆           ┆           ┆          │
# └───────────┴───────────┴───────────┴───────────┴───┴───────────┴───────────┴───────────┴──────────┘

# %%
site_counts = df['V2SOURCECOMMONNAME'].value_counts().to_pandas()
site_counts
# Out:
#            V2SOURCECOMMONNAME  count
# 0             rashtranews.com     55
# 1      asiancorrespondent.com      1
# 2                    wsau.com    610
# 3                celebuzz.com      3
# 4      themaconcountynews.com      1
# ...                       ...    ...
# 13803    movietvtechgeeks.com      1
# 13804      journalofmusic.com      1
# 13805    ghanaiantimes.com.gh      2
# 13806          949therock.com      1
# 13807          runblogrun.com      3
#
# [13808 rows x 2 columns]
