# %%
import pandas as pd
import os
import warnings
warnings.filterwarnings('ignore')

# %%
path_to_data = r"../data/raw/ontime"

# %%
# This function reduces the memory usage of a DataFrame by downcasting numeric types
def downcast(df, verbose = True):
    start_memory = df.memory_usage().sum() / 1024 ** 2
    for col in df.columns:
        dtype_name = df[col].dtype.name
        if dtype_name == "object":
            pass
        elif dtype_name == "bool":
            df[col] = df[col].astype("int8")
        elif dtype_name.startswith("int") or (df[col].round() == df[col]).all():
            df[col] = pd.to_numeric(df[col], downcast = "integer")
        else:
            df[col] = pd.to_numeric(df[col], downcast = "float")
    end_memory = df.memory_usage().sum() / 1024 ** 2

    if verbose:
        print("{:.1f}% compressed".format(100 * (start_memory - end_memory) / start_memory))

    return df

# %%
df = pd.read_csv(f'{path_to_data}/_2018_1/_2018_1.csv', low_memory=False)

# %%
df
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2018        1      1          14          7  2018-01-14
# 1       2018        1      1          15          1  2018-01-15
# 2       2018        1      1          16          2  2018-01-16
# 3       2018        1      1          17          3  2018-01-17
# 4       2018        1      1          18          4  2018-01-18
# ...      ...      ...    ...         ...        ...         ...
# 621393  2018        1      1          23          2  2018-01-23
# 621394  2018        1      1          24          3  2018-01-24
# 621395  2018        1      1          25          4  2018-01-25
# 621396  2018        1      1          26          5  2018-01-26
# 621397  2018        1      1          27          6  2018-01-27
#
#        Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                             UA                            UA_CODESHARE
# 1                             UA                            UA_CODESHARE
# 2                             UA                            UA_CODESHARE
# 3                             UA                            UA_CODESHARE
# 4                             UA                            UA_CODESHARE
# ...                          ...                                     ...
# 621393                        AA                                      AA
# 621394                        AA                                      AA
# 621395                        AA                                      AA
# 621396                        AA                                      AA
# 621397                        AA                                      AA
#
#         DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  ...  \
# 0                          19977                          UA  ...
# 1                          19977                          UA  ...
# 2                          19977                          UA  ...
# 3                          19977                          UA  ...
# 4                          19977                          UA  ...
# ...                          ...                         ...  ...
# 621393                     19805                          AA  ...
# 621394                     19805                          AA  ...
# 621395                     19805                          AA  ...
# 621396                     19805                          AA  ...
# 621397                     19805                          AA  ...
#
#         Div5Airport Div5AirportID  Div5AirportSeqID Div5WheelsOn  \
# 0               NaN           NaN               NaN          NaN
# 1               NaN           NaN               NaN          NaN
# 2               NaN           NaN               NaN          NaN
# 3               NaN           NaN               NaN          NaN
# 4               NaN           NaN               NaN          NaN
# ...             ...           ...               ...          ...
# 621393          NaN           NaN               NaN          NaN
# 621394          NaN           NaN               NaN          NaN
# 621395          NaN           NaN               NaN          NaN
# 621396          NaN           NaN               NaN          NaN
# 621397          NaN           NaN               NaN          NaN
#
#         Div5TotalGTime Div5LongestGTime  Div5WheelsOff Div5TailNum Duplicate  \
# 0                  NaN              NaN            NaN         NaN         N
# 1                  NaN              NaN            NaN         NaN         N
# 2                  NaN              NaN            NaN         NaN         N
# 3                  NaN              NaN            NaN         NaN         N
# 4                  NaN              NaN            NaN         NaN         N
# ...                ...              ...            ...         ...       ...
# 621393             NaN              NaN            NaN         NaN         N
# 621394             NaN              NaN            NaN         NaN         N
# 621395             NaN              NaN            NaN         NaN         N
# 621396             NaN              NaN            NaN         NaN         N
# 621397             NaN              NaN            NaN         NaN         N
#
#         Unnamed: 119
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 621393           NaN
# 621394           NaN
# 621395           NaN
# 621396           NaN
# 621397           NaN
#
# [621398 rows x 120 columns]

# %%
list(df.columns)
# Out:
# ['Year',
#  'Quarter',
#  'Month',
#  'DayofMonth',
#  'DayOfWeek',
#  'FlightDate',
#  'Marketing_Airline_Network',
#  'Operated_or_Branded_Code_Share_Partners',
#  'DOT_ID_Marketing_Airline',
#  'IATA_Code_Marketing_Airline',
#  'Flight_Number_Marketing_Airline',
#  'Originally_Scheduled_Code_Share_Airline',
#  'DOT_ID_Originally_Scheduled_Code_Share_Airline',
#  'IATA_Code_Originally_Scheduled_Code_Share_Airline',
#  'Flight_Num_Originally_Scheduled_Code_Share_Airline',
#  'Operating_Airline ',
#  'DOT_ID_Operating_Airline',
#  'IATA_Code_Operating_Airline',
#  'Tail_Number',
#  'Flight_Number_Operating_Airline',
#  'OriginAirportID',
#  'OriginAirportSeqID',
#  'OriginCityMarketID',
#  'Origin',
#  'OriginCityName',
#  'OriginState',
#  'OriginStateFips',
#  'OriginStateName',
#  'OriginWac',
#  'DestAirportID',
#  'DestAirportSeqID',
#  'DestCityMarketID',
#  'Dest',
#  'DestCityName',
#  'DestState',
#  'DestStateFips',
#  'DestStateName',
#  'DestWac',
#  'CRSDepTime',
#  'DepTime',
#  'DepDelay',
#  'DepDelayMinutes',
#  'DepDel15',
#  'DepartureDelayGroups',
#  'DepTimeBlk',
#  'TaxiOut',
#  'WheelsOff',
#  'WheelsOn',
#  'TaxiIn',
#  'CRSArrTime',
#  'ArrTime',
#  'ArrDelay',
#  'ArrDelayMinutes',
#  'ArrDel15',
#  'ArrivalDelayGroups',
#  'ArrTimeBlk',
#  'Cancelled',
#  'CancellationCode',
#  'Diverted',
#  'CRSElapsedTime',
#  'ActualElapsedTime',
#  'AirTime',
#  'Flights',
#  'Distance',
#  'DistanceGroup',
#  'CarrierDelay',
#  'WeatherDelay',
#  'NASDelay',
#  'SecurityDelay',
#  'LateAircraftDelay',
#  'FirstDepTime',
#  'TotalAddGTime',
#  'LongestAddGTime',
#  'DivAirportLandings',
#  'DivReachedDest',
#  'DivActualElapsedTime',
#  'DivArrDelay',
#  'DivDistance',
#  'Div1Airport',
#  'Div1AirportID',
#  'Div1AirportSeqID',
#  'Div1WheelsOn',
#  'Div1TotalGTime',
#  'Div1LongestGTime',
#  'Div1WheelsOff',
#  'Div1TailNum',
#  'Div2Airport',
#  'Div2AirportID',
#  'Div2AirportSeqID',
#  'Div2WheelsOn',
#  'Div2TotalGTime',
#  'Div2LongestGTime',
#  'Div2WheelsOff',
#  'Div2TailNum',
#  'Div3Airport',
#  'Div3AirportID',
#  'Div3AirportSeqID',
#  'Div3WheelsOn',
#  'Div3TotalGTime',
#  'Div3LongestGTime',
#  'Div3WheelsOff',
#  'Div3TailNum',
#  'Div4Airport',
#  'Div4AirportID',
#  'Div4AirportSeqID',
#  'Div4WheelsOn',
#  'Div4TotalGTime',
#  'Div4LongestGTime',
#  'Div4WheelsOff',
#  'Div4TailNum',
#  'Div5Airport',
#  'Div5AirportID',
#  'Div5AirportSeqID',
#  'Div5WheelsOn',
#  'Div5TotalGTime',
#  'Div5LongestGTime',
#  'Div5WheelsOff',
#  'Div5TailNum',
#  'Duplicate',
#  'Unnamed: 119']

# %%
df = df[[
 'FlightDate',
 'Marketing_Airline_Network',
 'DOT_ID_Marketing_Airline',
 'Flight_Number_Marketing_Airline',
 'DOT_ID_Originally_Scheduled_Code_Share_Airline',
 'Flight_Num_Originally_Scheduled_Code_Share_Airline',
 'DOT_ID_Operating_Airline',
 'Tail_Number',
 'Flight_Number_Operating_Airline',
 'OriginAirportID',
 'OriginCityMarketID',
 'OriginState',
 'DestAirportID',
 'DestCityMarketID',
 'DestState',
 'DepTime',
 'DepDelay',
 'WheelsOff',
 'WheelsOn',
 'ArrTime',
 'ArrDelay',
 'Cancelled',
 'CancellationCode',
 'Diverted',
 'ActualElapsedTime',
 'Flights',
 'Distance',
 'CarrierDelay',
 'WeatherDelay',
 'NASDelay',
 'SecurityDelay',
 'LateAircraftDelay',
 'Duplicate']]

# %%
df = downcast(df, verbose = True)
# Out:
# 48.1% compressed

# %%
df
# Out:
#         FlightDate Marketing_Airline_Network  DOT_ID_Marketing_Airline  \
# 0       2018-01-14                        UA                     19977
# 1       2018-01-15                        UA                     19977
# 2       2018-01-16                        UA                     19977
# 3       2018-01-17                        UA                     19977
# 4       2018-01-18                        UA                     19977
# ...            ...                       ...                       ...
# 621393  2018-01-23                        AA                     19805
# 621394  2018-01-24                        AA                     19805
# 621395  2018-01-25                        AA                     19805
# 621396  2018-01-26                        AA                     19805
# 621397  2018-01-27                        AA                     19805
#
#         Flight_Number_Marketing_Airline  \
# 0                                  4443
# 1                                  4443
# 2                                  4443
# 3                                  4443
# 4                                  4443
# ...                                 ...
# 621393                              407
# 621394                              407
# 621395                              407
# 621396                              407
# 621397                              407
#
#         DOT_ID_Originally_Scheduled_Code_Share_Airline  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 621393                                             NaN
# 621394                                             NaN
# 621395                                             NaN
# 621396                                             NaN
# 621397                                             NaN
#
#         Flight_Num_Originally_Scheduled_Code_Share_Airline  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 621393                                                NaN
# 621394                                                NaN
# 621395                                                NaN
# 621396                                                NaN
# 621397                                                NaN
#
#         DOT_ID_Operating_Airline Tail_Number  Flight_Number_Operating_Airline  \
# 0                          20366      N14902                             4443
# 1                          20366      N12167                             4443
# 2                          20366      N11109                             4443
# 3                          20366      N16546                             4443
# 4                          20366      N11165                             4443
# ...                          ...         ...                              ...
# 621393                     19805      N170US                              407
# 621394                     19805      N979UY                              407
# 621395                     19805      N182UW                              407
# 621396                     19805      N580UW                              407
# 621397                     19805      N926UW                              407
#
#         OriginAirportID  ...  Diverted ActualElapsedTime  Flights  Distance  \
# 0                 11618  ...         0             151.0        1       628
# 1                 11618  ...         0             141.0        1       628
# 2                 11618  ...         0             131.0        1       628
# 3                 11618  ...         0             138.0        1       628
# 4                 11618  ...         0             134.0        1       628
# ...                 ...  ...       ...               ...      ...       ...
# 621393            14100  ...         0             191.0        1      1013
# 621394            14100  ...         0             179.0        1      1013
# 621395            14100  ...         0             173.0        1      1013
# 621396            14100  ...         0             155.0        1      1013
# 621397            14100  ...         0             177.0        1      1013
#
#        CarrierDelay  WeatherDelay  NASDelay  SecurityDelay  LateAircraftDelay  \
# 0               NaN           NaN       NaN            NaN                NaN
# 1              41.0           0.0       0.0            0.0                0.0
# 2              67.0           0.0       0.0            0.0                2.0
# 3               NaN           NaN       NaN            NaN                NaN
# 4               NaN           NaN       NaN            NaN                NaN
# ...             ...           ...       ...            ...                ...
# 621393          NaN           NaN       NaN            NaN                NaN
# 621394          NaN           NaN       NaN            NaN                NaN
# 621395          NaN           NaN       NaN            NaN                NaN
# 621396          NaN           NaN       NaN            NaN                NaN
# 621397          NaN           NaN       NaN            NaN                NaN
#
#         Duplicate
# 0               N
# 1               N
# 2               N
# 3               N
# 4               N
# ...           ...
# 621393          N
# 621394          N
# 621395          N
# 621396          N
# 621397          N
#
# [621398 rows x 33 columns]

# %%
# Get the list of all csv files in path_to_data and all subfolders
csv_files = []
for root, dirs, files in os.walk(path_to_data):
    for f in files:
        if f.endswith('.csv'):
            csv_files.append(os.path.join(root, f))
csv_files
# Out:
# ['../data/raw/ontime\\_2018_1\\_2018_1.csv',
#  '../data/raw/ontime\\_2018_10\\_2018_10.csv',
#  '../data/raw/ontime\\_2018_11\\_2018_11.csv',
#  '../data/raw/ontime\\_2018_12\\_2018_12.csv',
#  '../data/raw/ontime\\_2018_2\\_2018_2.csv',
#  '../data/raw/ontime\\_2018_3\\_2018_3.csv',
#  '../data/raw/ontime\\_2018_4\\_2018_4.csv',
#  '../data/raw/ontime\\_2018_5\\_2018_5.csv',
#  '../data/raw/ontime\\_2018_6\\_2018_6.csv',
#  '../data/raw/ontime\\_2018_7\\_2018_7.csv',
#  '../data/raw/ontime\\_2018_8\\_2018_8.csv',
#  '../data/raw/ontime\\_2018_9\\_2018_9.csv',
#  '../data/raw/ontime\\_2019_1\\_2019_1.csv',
#  '../data/raw/ontime\\_2019_10\\_2019_10.csv',
#  '../data/raw/ontime\\_2019_11\\_2019_11.csv',
#  '../data/raw/ontime\\_2019_12\\_2019_12.csv',
#  '../data/raw/ontime\\_2019_2\\_2019_2.csv',
#  '../data/raw/ontime\\_2019_3\\_2019_3.csv',
#  '../data/raw/ontime\\_2019_4\\_2019_4.csv',
#  '../data/raw/ontime\\_2019_5\\_2019_5.csv',
#  '../data/raw/ontime\\_2019_6\\_2019_6.csv',
#  '../data/raw/ontime\\_2019_7\\_2019_7.csv',
#  '../data/raw/ontime\\_2019_8\\_2019_8.csv',
#  '../data/raw/ontime\\_2019_9\\_2019_9.csv',
#  '../data/raw/ontime\\_2020_1\\_2020_1.csv',
#  '../data/raw/ontime\\_2020_10\\_2020_10.csv',
#  '../data/raw/ontime\\_2020_11\\_2020_11.csv',
#  '../data/raw/ontime\\_2020_12\\_2020_12.csv',
#  '../data/raw/ontime\\_2020_2\\_2020_2.csv',
#  '../data/raw/ontime\\_2020_3\\_2020_3.csv',
#  '../data/raw/ontime\\_2020_4\\_2020_4.csv',
#  '../data/raw/ontime\\_2020_5\\_2020_5.csv',
#  '../data/raw/ontime\\_2020_6\\_2020_6.csv',
#  '../data/raw/ontime\\_2020_7\\_2020_7.csv',
#  '../data/raw/ontime\\_2020_8\\_2020_8.csv',
#  '../data/raw/ontime\\_2020_9\\_2020_9.csv',
#  '../data/raw/ontime\\_2021_1\\_2021_1.csv',
#  '../data/raw/ontime\\_2021_10\\_2021_10.csv',
#  '../data/raw/ontime\\_2021_11\\_2021_11.csv',
#  '../data/raw/ontime\\_2021_12\\_2021_12.csv',
#  '../data/raw/ontime\\_2021_2\\_2021_2.csv',
#  '../data/raw/ontime\\_2021_3\\_2021_3.csv',
#  '../data/raw/ontime\\_2021_4\\_2021_4.csv',
#  '../data/raw/ontime\\_2021_5\\_2021_5.csv',
#  '../data/raw/ontime\\_2021_6\\_2021_6.csv',
#  '../data/raw/ontime\\_2021_7\\_2021_7.csv',
#  '../data/raw/ontime\\_2021_8\\_2021_8.csv',
#  '../data/raw/ontime\\_2021_9\\_2021_9.csv',
#  '../data/raw/ontime\\_2022_1\\_2022_1.csv',
#  '../data/raw/ontime\\_2022_10\\_2022_10.csv',
#  '../data/raw/ontime\\_2022_11\\_2022_11.csv',
#  '../data/raw/ontime\\_2022_12\\_2022_12.csv',
#  '../data/raw/ontime\\_2022_2\\_2022_2.csv',
#  '../data/raw/ontime\\_2022_3\\_2022_3.csv',
#  '../data/raw/ontime\\_2022_4\\_2022_4.csv',
#  '../data/raw/ontime\\_2022_5\\_2022_5.csv',
#  '../data/raw/ontime\\_2022_6\\_2022_6.csv',
#  '../data/raw/ontime\\_2022_7\\_2022_7.csv',
#  '../data/raw/ontime\\_2022_8\\_2022_8.csv',
#  '../data/raw/ontime\\_2022_9\\_2022_9.csv',
#  '../data/raw/ontime\\_2023_1\\_2023_1.csv',
#  '../data/raw/ontime\\_2023_10\\_2023_10.csv',
#  '../data/raw/ontime\\_2023_11\\_2023_11.csv',
#  '../data/raw/ontime\\_2023_12\\_2023_12.csv',
#  '../data/raw/ontime\\_2023_2\\_2023_2.csv',
#  '../data/raw/ontime\\_2023_3\\_2023_3.csv',
#  '../data/raw/ontime\\_2023_4\\_2023_4.csv',
#  '../data/raw/ontime\\_2023_5\\_2023_5.csv',
#  '../data/raw/ontime\\_2023_6\\_2023_6.csv',
#  '../data/raw/ontime\\_2023_7\\_2023_7.csv',
#  '../data/raw/ontime\\_2023_8\\_2023_8.csv',
#  '../data/raw/ontime\\_2023_9\\_2023_9.csv',
#  '../data/raw/ontime\\_2024_1\\_2024_1.csv',
#  '../data/raw/ontime\\_2024_10\\_2024_10.csv',
#  '../data/raw/ontime\\_2024_11\\_2024_11.csv',
#  '../data/raw/ontime\\_2024_12\\_2024_12.csv',
#  '../data/raw/ontime\\_2024_2\\_2024_2.csv',
#  '../data/raw/ontime\\_2024_3\\_2024_3.csv',
#  '../data/raw/ontime\\_2024_4\\_2024_4.csv',
#  '../data/raw/ontime\\_2024_5\\_2024_5.csv',
#  '../data/raw/ontime\\_2024_6\\_2024_6.csv',
#  '../data/raw/ontime\\_2024_7\\_2024_7.csv',
#  '../data/raw/ontime\\_2024_8\\_2024_8.csv',
#  '../data/raw/ontime\\_2024_9\\_2024_9.csv',
#  '../data/raw/ontime\\_2025_1\\_2025_1.csv']

# %%
def load_data(file):
    df = pd.read_csv(file, low_memory=False)
    df = df[[
     'FlightDate',
     'Marketing_Airline_Network',
     'DOT_ID_Marketing_Airline',
     'Flight_Number_Marketing_Airline',
     'DOT_ID_Originally_Scheduled_Code_Share_Airline',
     'Flight_Num_Originally_Scheduled_Code_Share_Airline',
     'DOT_ID_Operating_Airline',
     'Tail_Number',
     'Flight_Number_Operating_Airline',
     'OriginAirportID',
     'OriginCityMarketID',
     'OriginState',
     'DestAirportID',
     'DestCityMarketID',
     'DestState',
     'DepTime',
     'DepDelay',
     'WheelsOff',
     'WheelsOn',
     'ArrTime',
     'ArrDelay',
     'Cancelled',
     'CancellationCode',
     'Diverted',
     'ActualElapsedTime',
     'Flights',
     'Distance',
     'CarrierDelay',
     'WeatherDelay',
     'NASDelay',
     'SecurityDelay',
     'LateAircraftDelay']]
    return df

# %%
# Loop through the files, limiting columns and appending to a df
for file in csv_files:
    if file == csv_files[0]:
        df_main = load_data(file)
    else:
        df_temp = load_data(file)
        df_main = pd.concat([df_main, df_temp], ignore_index=True)

df_main = downcast(df_main, verbose = True)
df_main
